# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruanshijinquan/homeworks/blob/main/homeworks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cmath
import matplotlib.pyplot as plt
import numpy as np

delta = (b**2) - (4*a*c)

x1 = (-b - cmath.sqrt(delta)) / (2 * a)
x2 = (-b + cmath.sqrt(delta)) / (2 * a)


 print('Nghiem phuong trình la: {0} and {1}'.format(X1,X2))

x = np.linspace(-10, 10, 1000)
y = a*x**2 + b*x + c

fig, ax = plt.subplots(figsize=(10,10))

ax.plot(x,y,color='green', linewidth=6) 
plt.axvline(x=X1.real,color='r', linestyle='- -',linewidth=3) 
plt.axvline(x=X2.real,color='b', linestyles='- -',Linewidth=3) 
plt.axhline(y=0,color='k', linestyle='- -', linewidth=3)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
return X1,X2
X1,X2 = giai_phuong_trinh_bac_2(2,-7,3)
# Out:
#   File "<ipython-input-25-ff9960d9bc86>", line 11
#     print('Nghiem phuong trình la: {0} and {1}'.format(X1,X2))
#     ^
# IndentationError: unexpected indent

# %%
7# Thu vien
import math


# Nhap du lieu
a = float(input('Nhap he so a: '))
while a == 0:
    if a == 0:
        print('Hay nhap lai he so a!')
        a = float(input('Nhap he so a: '))
b = float(input('Nhap he so b: '))
while b == 0:
    if b == 0:
        print('Hay nhap lai he so b!')
        b = float(input('Nhap he so b: '))
c = float(input('Nhap he so c: '))

# Giai va bien luan
delta = b * b - 4 * a * c
if delta > 0:
    x1 = (-b + math.sqrt(delta)) / (2 * a)
    x2 = (-b - math.sqrt(delta)) / (2 * a)
    print('Phuong trinh co 2 nghiem phan biet la:')
    print('x1 = ', x1)
    print('x2 = ', x2)
elif delta == 0:
    x = -b / (2 * a)
    print('Phuong trinh co nghiem kep la:')
    print('x1 = x2 = ', x)
else:
    print('Phuong trinh vo nghiem')
# DO THI
    x = np.linspace(-10, 10, 1000)
y = a*x**2 + b*x + c

fig, ax = plt.subplots(figsize=(10,10))

ax.plot(x,y,color='green', linewidth=6) 
plt.axvline(x=X1.real,color='r', linestyle='- -',linewidth=3) 
plt.axvline(x=X2.real,color='b', linestyles='- -',Linewidth=3) 
plt.axhline(y=0,color='k', linestyle='- -', linewidth=3)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
X1,X2
# Out:
# Nhap he so a: -3
# Nhap he so b: 4
# Nhap he so c: 7
# Phuong trinh co 2 nghiem phan biet la:
# x1 =  -1.0
# x2 =  2.3333333333333335
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-3bb92e5fd0ce> in <cell line: 39>()
#      37
#      38 ax.plot(x,y,color='green', linewidth=6)
# ---> 39 plt.axvline(x=X1.real,color='r', linestyle='- -',linewidth=3)
#      40 plt.axvline(x=X2.real,color='b', linestyles='- -',Linewidth=3)
#      41 plt.axhline(y=0,color='k', linestyle='- -', linewidth=3)
#
# NameError: name 'X1' is not defined

# %%
7# Thu vien
import math


# Nhap du lieu
a = float(input('Nhap he so a: '))
while a == 0:
    if a == 0:
        print('Hay nhap lai he so a!')
        a = float(input('Nhap he so a: '))
b = float(input('Nhap he so b: '))
while b == 0:
    if b == 0:
        print('Hay nhap lai he so b!')
        b = float(input('Nhap he so b: '))
c = float(input('Nhap he so c: '))

# Giai va bien luan
delta = b * b - 4 * a * c
if delta > 0:
    x1 = (-b + math.sqrt(delta)) / (2 * a)
    x2 = (-b - math.sqrt(delta)) / (2 * a)
    print('Phuong trinh co 2 nghiem phan biet la:')
    print('x1 = ', x1)
    print('x2 = ', x2)
elif delta == 0:
    x = -b / (2 * a)
    print('Phuong trinh co nghiem kep la:')
    print('x1 = x2 = ', x)
else:
    print('Phuong trinh vo nghiem')
# DO THI
    x = np.linspace(-10, 10, 1000)
y = a*x**2 + b*x + c

fig, ax = plt.subplots(figsize=(10,10))

ax.plot(x,y,color='green', linewidth=6) 
plt.axvline(x=X1.real,color='r', linestyle='- -',linewidth=3) 
plt.axvline(x=X2.real,color='b', linestyles='- -',Linewidth=3) 
plt.axhline(y=0,color='k', linestyle='- -', linewidth=3)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
X1,X2
# Out:
# Nhap he so a: 5
# Nhap he so b: -4
# Nhap he so c: 9
# Phuong trinh vo nghiem
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-c1d971caabd5> in <cell line: 39>()
#      37
#      38 ax.plot(x,y,color='green', linewidth=6)
# ---> 39 plt.axvline(x=X1.real,color='r', linestyle='- -',linewidth=3)
#      40 plt.axvline(x=X2.real,color='b', linestyles='- -',Linewidth=3)
#      41 plt.axhline(y=0,color='k', linestyle='- -', linewidth=3)
#
# NameError: name 'X1' is not defined
