# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruanshijinquan/homeworks/blob/main/homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for a in range(1, 1000 + 1):
    if(a % 2 !=0) and (a % 3 !=0) and (a % 5 !=0) and (a % 7 !=0):
     print("不能被，3,5,7整除的數字:",a)
print(len(a))
# Out:
# 不能被，3,5,7整除的數字: 1
# 不能被，3,5,7整除的數字: 11
# 不能被，3,5,7整除的數字: 13
# 不能被，3,5,7整除的數字: 17
# 不能被，3,5,7整除的數字: 19
# 不能被，3,5,7整除的數字: 23
# 不能被，3,5,7整除的數字: 29
# 不能被，3,5,7整除的數字: 31
# 不能被，3,5,7整除的數字: 37
# 不能被，3,5,7整除的數字: 41
# 不能被，3,5,7整除的數字: 43
# 不能被，3,5,7整除的數字: 47
# 不能被，3,5,7整除的數字: 53
# 不能被，3,5,7整除的數字: 59
# 不能被，3,5,7整除的數字: 61
# 不能被，3,5,7整除的數字: 67
# 不能被，3,5,7整除的數字: 71
# 不能被，3,5,7整除的數字: 73
# 不能被，3,5,7整除的數字: 79
# 不能被，3,5,7整除的數字: 83
# 不能被，3,5,7整除的數字: 89
# 不能被，3,5,7整除的數字: 97
# 不能被，3,5,7整除的數字: 101
# 不能被，3,5,7整除的數字: 103
# 不能被，3,5,7整除的數字: 107
# 不能被，3,5,7整除的數字: 109
# 不能被，3,5,7整除的數字: 113
# 不能被，3,5,7整除的數字: 121
# 不能被，3,5,7整除的數字: 127
# 不能被，3,5,7整除的數字: 131
# 不能被，3,5,7整除的數字: 137
# 不能被，3,5,7整除的數字: 139
# 不能被，3,5,7整除的數字: 143
# 不能被，3,5,7整除的數字: 149
# 不能被，3,5,7整除的數字: 151
# 不能被，3,5,7整除的數字: 157
# 不能被，3,5,7整除的數字: 163
# 不能被，3,5,7整除的數字: 167
# 不能被，3,5,7整除的數字: 169
# 不能被，3,5,7整除的數字: 173
# 不能被，3,5,7整除的數字: 179
# 不能被，3,5,7整除的數字: 181
# 不能被，3,5,7整除的數字: 187
# 不能被，3,5,7整除的數字: 191
# 不能被，3,5,7整除的數字: 193
# 不能被，3,5,7整除的數字: 197
# 不能被，3,5,7整除的數字: 199
# 不能被，3,5,7整除的數字: 209
# 不能被，3,5,7整除的數字: 211
# 不能被，3,5,7整除的數字: 221
# 不能被，3,5,7整除的數字: 223
# 不能被，3,5,7整除的數字: 227
# 不能被，3,5,7整除的數字: 229
# 不能被，3,5,7整除的數字: 233
# 不能被，3,5,7整除的數字: 239
# 不能被，3,5,7整除的數字: 241
# 不能被，3,5,7整除的數字: 247
# 不能被，3,5,7整除的數字: 251
# 不能被，3,5,7整除的數字: 253
# 不能被，3,5,7整除的數字: 257
# 不能被，3,5,7整除的數字: 263
# 不能被，3,5,7整除的數字: 269
# 不能被，3,5,7整除的數字: 271
# 不能被，3,5,7整除的數字: 277
# 不能被，3,5,7整除的數字: 281
# 不能被，3,5,7整除的數字: 283
# 不能被，3,5,7整除的數字: 289
# 不能被，3,5,7整除的數字: 293
# 不能被，3,5,7整除的數字: 299
# 不能被，3,5,7整除的數字: 307
# 不能被，3,5,7整除的數字: 311
# 不能被，3,5,7整除的數字: 313
# 不能被，3,5,7整除的數字: 317
# 不能被，3,5,7整除的數字: 319
# 不能被，3,5,7整除的數字: 323
# 不能被，3,5,7整除的數字: 331
# 不能被，3,5,7整除的數字: 337
# 不能被，3,5,7整除的數字: 341
# 不能被，3,5,7整除的數字: 347
# 不能被，3,5,7整除的數字: 349
# 不能被，3,5,7整除的數字: 353
# 不能被，3,5,7整除的數字: 359
# 不能被，3,5,7整除的數字: 361
# 不能被，3,5,7整除的數字: 367
# 不能被，3,5,7整除的數字: 373
# 不能被，3,5,7整除的數字: 377
# 不能被，3,5,7整除的數字: 379
# 不能被，3,5,7整除的數字: 383
# 不能被，3,5,7整除的數字: 389
# 不能被，3,5,7整除的數字: 391
# 不能被，3,5,7整除的數字: 397
# 不能被，3,5,7整除的數字: 401
# 不能被，3,5,7整除的數字: 403
# 不能被，3,5,7整除的數字: 407
# 不能被，3,5,7整除的數字: 409
# 不能被，3,5,7整除的數字: 419
# 不能被，3,5,7整除的數字: 421
# 不能被，3,5,7整除的數字: 431
# 不能被，3,5,7整除的數字: 433
# 不能被，3,5,7整除的數字: 437
# 不能被，3,5,7整除的數字: 439
# 不能被，3,5,7整除的數字: 443
# 不能被，3,5,7整除的數字: 449
# 不能被，3,5,7整除的數字: 451
# 不能被，3,5,7整除的數字: 457
# 不能被，3,5,7整除的數字: 461
# 不能被，3,5,7整除的數字: 463
# 不能被，3,5,7整除的數字: 467
# 不能被，3,5,7整除的數字: 473
# 不能被，3,5,7整除的數字: 479
# 不能被，3,5,7整除的數字: 481
# 不能被，3,5,7整除的數字: 487
# 不能被，3,5,7整除的數字: 491
# 不能被，3,5,7整除的數字: 493
# 不能被，3,5,7整除的數字: 499
# 不能被，3,5,7整除的數字: 503
# 不能被，3,5,7整除的數字: 509
# 不能被，3,5,7整除的數字: 517
# 不能被，3,5,7整除的數字: 521
# 不能被，3,5,7整除的數字: 523
# 不能被，3,5,7整除的數字: 527
# 不能被，3,5,7整除的數字: 529
# 不能被，3,5,7整除的數字: 533
# 不能被，3,5,7整除的數字: 541
# 不能被，3,5,7整除的數字: 547
# 不能被，3,5,7整除的數字: 551
# 不能被，3,5,7整除的數字: 557
# 不能被，3,5,7整除的數字: 559
# 不能被，3,5,7整除的數字: 563
# 不能被，3,5,7整除的數字: 569
# 不能被，3,5,7整除的數字: 571
# 不能被，3,5,7整除的數字: 577
# 不能被，3,5,7整除的數字: 583
# 不能被，3,5,7整除的數字: 587
# 不能被，3,5,7整除的數字: 589
# 不能被，3,5,7整除的數字: 593
# 不能被，3,5,7整除的數字: 599
# 不能被，3,5,7整除的數字: 601
# 不能被，3,5,7整除的數字: 607
# 不能被，3,5,7整除的數字: 611
# 不能被，3,5,7整除的數字: 613
# 不能被，3,5,7整除的數字: 617
# 不能被，3,5,7整除的數字: 619
# 不能被，3,5,7整除的數字: 629
# 不能被，3,5,7整除的數字: 631
# 不能被，3,5,7整除的數字: 641
# 不能被，3,5,7整除的數字: 643
# 不能被，3,5,7整除的數字: 647
# 不能被，3,5,7整除的數字: 649
# 不能被，3,5,7整除的數字: 653
# 不能被，3,5,7整除的數字: 659
# 不能被，3,5,7整除的數字: 661
# 不能被，3,5,7整除的數字: 667
# 不能被，3,5,7整除的數字: 671
# 不能被，3,5,7整除的數字: 673
# 不能被，3,5,7整除的數字: 677
# 不能被，3,5,7整除的數字: 683
# 不能被，3,5,7整除的數字: 689
# 不能被，3,5,7整除的數字: 691
# 不能被，3,5,7整除的數字: 697
# 不能被，3,5,7整除的數字: 701
# 不能被，3,5,7整除的數字: 703
# 不能被，3,5,7整除的數字: 709
# 不能被，3,5,7整除的數字: 713
# 不能被，3,5,7整除的數字: 719
# 不能被，3,5,7整除的數字: 727
# 不能被，3,5,7整除的數字: 731
# 不能被，3,5,7整除的數字: 733
# 不能被，3,5,7整除的數字: 737
# 不能被，3,5,7整除的數字: 739
# 不能被，3,5,7整除的數字: 743
# 不能被，3,5,7整除的數字: 751
# 不能被，3,5,7整除的數字: 757
# 不能被，3,5,7整除的數字: 761
# 不能被，3,5,7整除的數字: 767
# 不能被，3,5,7整除的數字: 769
# 不能被，3,5,7整除的數字: 773
# 不能被，3,5,7整除的數字: 779
# 不能被，3,5,7整除的數字: 781
# 不能被，3,5,7整除的數字: 787
# 不能被，3,5,7整除的數字: 793
# 不能被，3,5,7整除的數字: 797
# 不能被，3,5,7整除的數字: 799
# 不能被，3,5,7整除的數字: 803
# 不能被，3,5,7整除的數字: 809
# 不能被，3,5,7整除的數字: 811
# 不能被，3,5,7整除的數字: 817
# 不能被，3,5,7整除的數字: 821
# 不能被，3,5,7整除的數字: 823
# 不能被，3,5,7整除的數字: 827
# 不能被，3,5,7整除的數字: 829
# 不能被，3,5,7整除的數字: 839
# 不能被，3,5,7整除的數字: 841
# 不能被，3,5,7整除的數字: 851
# 不能被，3,5,7整除的數字: 853
# 不能被，3,5,7整除的數字: 857
# 不能被，3,5,7整除的數字: 859
# 不能被，3,5,7整除的數字: 863
# 不能被，3,5,7整除的數字: 869
# 不能被，3,5,7整除的數字: 871
# 不能被，3,5,7整除的數字: 877
# 不能被，3,5,7整除的數字: 881
# 不能被，3,5,7整除的數字: 883
# 不能被，3,5,7整除的數字: 887
# 不能被，3,5,7整除的數字: 893
# 不能被，3,5,7整除的數字: 899
# 不能被，3,5,7整除的數字: 901
# 不能被，3,5,7整除的數字: 907
# 不能被，3,5,7整除的數字: 911
# 不能被，3,5,7整除的數字: 913
# 不能被，3,5,7整除的數字: 919
# 不能被，3,5,7整除的數字: 923
# 不能被，3,5,7整除的數字: 929
# 不能被，3,5,7整除的數字: 937
# 不能被，3,5,7整除的數字: 941
# 不能被，3,5,7整除的數字: 943
# 不能被，3,5,7整除的數字: 947
# 不能被，3,5,7整除的數字: 949
# 不能被，3,5,7整除的數字: 953
# 不能被，3,5,7整除的數字: 961
# 不能被，3,5,7整除的數字: 967
# 不能被，3,5,7整除的數字: 971
# 不能被，3,5,7整除的數字: 977
# 不能被，3,5,7整除的數字: 979
# 不能被，3,5,7整除的數字: 983
# 不能被，3,5,7整除的數字: 989
# 不能被，3,5,7整除的數字: 991
# 不能被，3,5,7整除的數字: 997
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-fbcd122ccc0a> in <module>
#       2     if(a % 2 !=0) and (a % 3 !=0) and (a % 5 !=0) and (a % 7 !=0):
#       3      print("不能被，3,5,7整除的數字:",a)
# ----> 4 print(len(a))
#       5
#       6
#
# TypeError: object of type 'int' has no len()
